# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

# List of countries
countries = [
    "united-states", "euro-area", "china", "japan", "germany", "united-kingdom", "france", "india", "italy", "brazil",
    "canada", "south-korea", "russia", "spain", "australia", "mexico", "indonesia", "turkey", "netherlands", "switzerland",
    "saudi-arabia", "argentina", "south-africa", "singapore", "america", "antigua-and-barbuda", "aruba",
    "bahamas", "barbados", "belize", "bermuda", "bolivia", "cayman-islands", "chile", "colombia",
    "costa-rica", "cuba", "dominica", "dominican-republic", "ecuador", "el-salvador", "grenada", "guatemala", "guyana",
    "haiti", "honduras", "jamaica", "nicaragua", "panama", "paraguay", "peru", "puerto-rico", "suriname",
    "trinidad-and-tobago", "uruguay", "venezuela", "albania", "andorra", "austria", "belarus",
    "belgium", "bosnia-and-herzegovina", "bulgaria", "croatia", "cyprus", "czech-republic", "denmark", "estonia",
    "finland", "greece", "hungary", "iceland", "ireland", "isle-of-man", "kosovo", "latvia", "liechtenstein",
    "lithuania", "luxembourg", "malta", "moldova", "monaco", "montenegro", "north-macedonia", "norway", "poland",
    "portugal", "romania", "serbia", "slovakia", "slovenia", "sweden", "ukraine", "algeria", "angola", "benin", "botswana",
    "burkina-faso", "burundi", "cameroon", "cape-verde", "central-african-republic", "chad", "comoros", "congo", "djibouti",
    "egypt", "equatorial-guinea", "eritrea", "ethiopia", "gabon", "gambia", "ghana", "guinea", "guinea-bissau", "ivory-coast", "kenya",
    "lesotho", "liberia", "libya", "madagascar", "malawi", "mali", "mauritania", "mauritius", "morocco", "mozambique",
    "namibia", "niger", "nigeria", "republic-of-the-congo", "rwanda", "sao-tome-and-principe", "senegal", "seychelles",
    "sierra-leone", "somalia", "south-sudan", "sudan", "swaziland", "tanzania", "togo", "tunisia", "uganda", "zambia", "zimbabwe",
    "afghanistan", "armenia", "azerbaijan", "bahrain", "bangladesh", "bhutan", "brunei", "cambodia",
    "east-timor", "georgia", "hong-kong", "iran", "iraq", "israel", "jordan",
    "kazakhstan", "kuwait", "kyrgyzstan", "laos", "lebanon", "macao", "malaysia", "maldives", "mongolia", "myanmar", "nepal",
    "north-korea", "oman", "palestine", "pakistan", "philippines", "qatar", "united-arab-emirates", "uzbekistan", "vietnam",
    "yemen", "fiji", "kiribati", "new-caledonia", "new-zealand", "papua-new-guinea", "samoa", "solomon-islands",
    "tonga", "vanuatu"
]

# Output CSV file
filename = "global_exports_by_country.csv"

# Open the CSV file for writing
with open(filename, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["Country", "Partner Country", "Export Value (Million USD)"])  # Write headers

    headers = {"User-Agent": "Mozilla/5.0"}  # Set a user agent to avoid blocking

    for country in countries:
        url = f"https://tradingeconomics.com/{country}/exports-by-country"
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            soup = BeautifulSoup(response.text, "html.parser")
            table = soup.find("table", class_="table table-hover")

            if table:
                for tr in table.find_all("tr")[1:11]:  # Extract only the first 10 rows per country
                    cells = [td.text.strip() for td in tr.find_all("td")]
                    if cells:
                        writer.writerow([country] + cells)
                print(f"Data for {country} saved.")
            else:
                print(f"No table found for {country}.")
        else:
            print(f"Failed to retrieve data for {country}. Status code: {response.status_code}")

        time.sleep(1)  # Adding a delay to avoid being blocked

print(f"All data successfully saved to {filename}")
# Out:
# Data for united-states saved.
# No table found for euro-area.
# Data for china saved.
# Data for japan saved.
# Data for germany saved.
# Data for united-kingdom saved.
# Data for france saved.
# Data for india saved.
# Data for italy saved.
# Data for brazil saved.
# Data for canada saved.
# Data for south-korea saved.
# Data for russia saved.
# Data for spain saved.
# Data for australia saved.
# Data for mexico saved.
# Data for indonesia saved.
# Data for turkey saved.
# Data for netherlands saved.
# Data for switzerland saved.
# Data for saudi-arabia saved.
# Data for argentina saved.
# Data for south-africa saved.
# Data for singapore saved.
# No table found for america.
# Data for antigua-and-barbuda saved.
# Data for aruba saved.
# Data for bahamas saved.
# Data for barbados saved.
# Data for belize saved.
# Data for bermuda saved.
# Data for bolivia saved.
# Data for cayman-islands saved.
# Data for chile saved.
# Data for colombia saved.
# Data for costa-rica saved.
# ...

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

# List of countries
countries = [
    "united-states", "euro-area", "china", "japan", "germany", "united-kingdom", "france", "india", "italy", "brazil",
    "canada", "south-korea", "russia", "spain", "australia", "mexico", "indonesia", "turkey", "netherlands", "switzerland",
    "saudi-arabia", "argentina", "south-africa", "singapore", "america", "antigua-and-barbuda", "aruba",
    "bahamas", "barbados", "belize", "bermuda", "bolivia", "cayman-islands", "chile", "colombia",
    "costa-rica", "cuba", "dominica", "dominican-republic", "ecuador", "el-salvador", "grenada", "guatemala", "guyana",
    "haiti", "honduras", "jamaica", "nicaragua", "panama", "paraguay", "peru", "puerto-rico", "suriname",
    "trinidad-and-tobago", "uruguay", "venezuela", "albania", "andorra", "austria", "belarus",
    "belgium", "bosnia-and-herzegovina", "bulgaria", "croatia", "cyprus", "czech-republic", "denmark", "estonia",
    "finland", "greece", "hungary", "iceland", "ireland", "isle-of-man", "kosovo", "latvia", "liechtenstein",
    "lithuania", "luxembourg", "malta", "moldova", "monaco", "montenegro", "north-macedonia", "norway", "poland",
    "portugal", "romania", "serbia", "slovakia", "slovenia", "sweden", "ukraine", "algeria", "angola", "benin", "botswana",
    "burkina-faso", "burundi", "cameroon", "cape-verde", "central-african-republic", "chad", "comoros", "congo", "djibouti",
    "egypt", "equatorial-guinea", "eritrea", "ethiopia", "gabon", "gambia", "ghana", "guinea", "guinea-bissau", "ivory-coast", "kenya",
    "lesotho", "liberia", "libya", "madagascar", "malawi", "mali", "mauritania", "mauritius", "morocco", "mozambique",
    "namibia", "niger", "nigeria", "republic-of-the-congo", "rwanda", "sao-tome-and-principe", "senegal", "seychelles",
    "sierra-leone", "somalia", "south-sudan", "sudan", "swaziland", "tanzania", "togo", "tunisia", "uganda", "zambia", "zimbabwe",
    "afghanistan", "armenia", "azerbaijan", "bahrain", "bangladesh", "bhutan", "brunei", "cambodia",
    "east-timor", "georgia", "hong-kong", "iran", "iraq", "israel", "jordan",
    "kazakhstan", "kuwait", "kyrgyzstan", "laos", "lebanon", "macao", "malaysia", "maldives", "mongolia", "myanmar", "nepal",
    "north-korea", "oman", "palestine", "pakistan", "philippines", "qatar", "united-arab-emirates", "uzbekistan", "vietnam",
    "yemen", "fiji", "kiribati", "new-caledonia", "new-zealand", "papua-new-guinea", "samoa", "solomon-islands",
    "tonga", "vanuatu"
]

# Output CSV file
filename = "global_imports_by_country.csv"

# Open the CSV file for writing
with open(filename, "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["Country", "Partner Country", "Import Value (Million USD)"])  # Write headers

    headers = {"User-Agent": "Mozilla/5.0"}  # Set a user agent to avoid blocking

    for country in countries:
        url = f"https://tradingeconomics.com/{country}/imports-by-country"
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            soup = BeautifulSoup(response.text, "html.parser")
            table = soup.find("table", class_="table table-hover")

            if table:
                for tr in table.find_all("tr")[1:11]:  # Extract only the first 10 rows per country
                    cells = [td.text.strip() for td in tr.find_all("td")]
                    if cells:
                        writer.writerow([country] + cells)
                print(f"Data for {country} saved.")
            else:
                print(f"No table found for {country}.")
        else:
            print(f"Failed to retrieve data for {country}. Status code: {response.status_code}")

        time.sleep(1)  # Adding a delay to avoid being blocked

print(f"All data successfully saved to {filename}")
# Out:
# Data for united-states saved.
# No table found for euro-area.
# Data for china saved.
# Data for japan saved.
# Data for germany saved.
# Data for united-kingdom saved.
# Data for france saved.
# Data for india saved.
# Data for italy saved.
# Data for brazil saved.
# Data for canada saved.
# Data for south-korea saved.
# Data for russia saved.
# Data for spain saved.
# Data for australia saved.
# Data for mexico saved.
# Data for indonesia saved.
# Data for turkey saved.
# Data for netherlands saved.
# Data for switzerland saved.
# Data for saudi-arabia saved.
# Data for argentina saved.
# Data for south-africa saved.
# Data for singapore saved.
# No table found for america.
# Data for antigua-and-barbuda saved.
# Data for aruba saved.
# Data for bahamas saved.
# Data for barbados saved.
# Data for belize saved.
# Data for bermuda saved.
# Data for bolivia saved.
# Data for cayman-islands saved.
# Data for chile saved.
# Data for colombia saved.
# Data for costa-rica saved.
# ...
